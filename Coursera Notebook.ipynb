# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Yu Heng Wu**
# <br> Data Scientist

# %% [markdown]
# *I am interested in data science because it's an intersection between statistics and computer science*

# %% [markdown]
#     <h3> My code assigns 9 and 12 to the variables a and b respectively, then mulitplies them

# %%
a = 9
b = 12
a*b
# Out:
# 108

# %% [markdown]
# ~~I strike this through~~
# <ol><li>
#     <p>This is a numbered list</p>
# </li></ol>
#
# This is a <hr> Horizontal rule
